# %%
import pandas as pd
import numpy as np

# %%
# Load datase
df = pd.read_csv('top_1000_wallet_scores.csv')

# %%
df.head(1000)
# Out:
#                                      Unnamed: 0  first_tx_time  last_tx_time  \
# 0    0x29fe7d60ddf151e5b52e5fab4f1325da6b2bd958      -1.115836     -0.520740
# 1    0xaa6e8127831c9de45ae56bb1b0d4d4da6e5665bd       1.006652      1.855969
# 2    0x00000000001876eb1444c986fd502e618c587430      -1.106095     -0.520802
# 3    0xa2b47e3d5c44877cca798226b7b8118f9bfb7a56      -1.029995     -0.520794
# 4    0xf859a1ad94bcf445a406b892ef0d3082f4174088       1.344375      1.856874
# ..                                          ...            ...           ...
# 995  0xa4517a2b21f85f6a6a63601cea7fa4e34da92856       0.777264      0.981613
# 996  0x241e1aac00ef9b5f8f22a9bd63c8e6b05bc709ba       1.109894      1.393740
# 997  0xffc5924dd727e6f081ef16b68403b8b322d870ec      -1.113734     -1.040883
# 998  0x58ad03b52aca614be263f34305b4659a66e4725a       1.003954      1.544592
# 999  0xe9947f9d6137be1efc8525384c49e964aeb4bcd9       0.698878      1.104129
#
# ...
